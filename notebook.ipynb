# %% [markdown]
# ## TRDE703 Atelier Intégration des Données

# %%
import os

from pyspark.sql import SparkSession

db_url = "jdbc:mysql://localhost:3306/openfoodfacts"
db_properties = {
    "user": "root",
    "password": "root",
    "driver": "com.mysql.cj.jdbc.Driver",
}
mysql_driver_path = os.path.abspath("installation/mysql-connector-j-9.1.0.jar")

# %%
spark = (
    SparkSession.builder.appName("Intégration_données")
    .config("spark.jars", mysql_driver_path)
    .config("spark.driver.extraJavaOptions", "--add-opens java.base/java.nio=ALL-UNNAMED --add-exports java.base/sun.nio.ch=ALL-UNNAMED")
    .config("spark.executor.extraJavaOptions", "--add-opens java.base/java.nio=ALL-UNNAMED --add-exports java.base/sun.nio.ch=ALL-UNNAMED")
    .getOrCreate()
)

print("✅ Spark initialisé avec le driver MySQL :", mysql_driver_path)
print("🔗 Driver chargé :", spark.sparkContext.getConf().get("spark.jars"))
# Out:
# 25/11/17 12:54:19 WARN Utils: Your hostname, MacBook-Pro-de-Cedric.local resolves to a loopback address: 127.0.0.1; using 172.31.105.72 instead (on interface en0)
# 25/11/17 12:54:19 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 25/11/17 12:54:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ✅ Spark initialisé avec le driver MySQL : /Users/cedricsanchez/Master1/Cours/integration_donnees_TP/installation/mysql-connector-j-9.1.0.jar
# 🔗 Driver chargé : /Users/cedricsanchez/Master1/Cours/integration_donnees_TP/installation/mysql-connector-j-9.1.0.jar
